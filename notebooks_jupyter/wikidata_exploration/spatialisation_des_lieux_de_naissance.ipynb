# %% [markdown]
# # Spatialisation des lieux de naissances

# %%
import geopandas as gpd

# %%
df_switzerland = gpd.read_file('import/switzerland.geojson')
print(df_switzerland.head())
df_switzerland.plot()
# Out:
#                                             geometry
# 0  POLYGON ((7.20034 45.87567, 7.20360 45.87686, ...
# <Axes: >
